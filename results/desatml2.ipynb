# %%
#%% ---------------------------------------------------------------------------
# desatml2.py  –  binary‑desaturation model for two data‑sets (SIesta & ESADA)
# ---------------------------------------------------------------------------

#%% ---------------------------------------------------------------------------
# Imports & utility callbacks
# ---------------------------------------------------------------------------
from __future__ import absolute_import, division, print_function
import os
import numpy as np
import keras
from datetime import datetime
import h5py
import pandas as pd                     # pandas for the results DataFrame

# scikit‑learn metrics
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)

# ---------------------------------------------------------------------------
# Helper callbacks
# ---------------------------------------------------------------------------
class PrintDot(keras.callbacks.Callback):
    """Print a dot every epoch (newline every 100 epochs)."""
    def on_epoch_end(self, epoch, logs=None):
        if epoch % 100 == 0:
            print(' ')
        print('#', end='')


class PrintBestEpoch(keras.callbacks.Callback):
    """Keeps track of the epoch with the lowest validation loss."""
    def on_train_begin(self, logs=None):
        self.best_value = np.inf
        self.best_epoch = 0

    def on_epoch_end(self, epoch, logs=None):
        val_loss = logs.get('val_loss')
        if val_loss is not None and val_loss < self.best_value:
            self.best_value = val_loss
            self.best_epoch = epoch

    def on_train_end(self, logs=None):
        print(f'Best epoch: {self.best_epoch + 1}')


#%% ---------------------------------------------------------------------------
# Hyper‑parameters (shared by both data‑sets)
# ---------------------------------------------------------------------------
VAL_SPLIT = 0.1
BATCH_SIZE = 20000
EPOCHS = 1000
EARLY_STOP_PATIENCE = 100
LRN_RATE = 0.0002
INPUT_DIM = 300          # each row in the DataMatrix files has 300 columns
NUM_CLASSES = 2          # binary classification


#%% ---------------------------------------------------------------------------
# Model definition (binary only)
# ---------------------------------------------------------------------------
def build_binary_model():
    """Return a compiled Keras model for the binary task."""
    model = keras.Sequential([
        keras.layers.Dense(30, activation='tanh', input_shape=(INPUT_DIM,)),
        keras.layers.Dense(10, activation='tanh'),
        keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    optimizer = keras.optimizers.Adam(LRN_RATE)
    model.compile(
        loss='mean_squared_error',
        optimizer=optimizer,
        metrics=['accuracy']
    )
    model.summary()
    return model


#%% ---------------------------------------------------------------------------
# Training helper
# ---------------------------------------------------------------------------
def train_model(model, train_X, train_y_onehot,
                model_path, weights_path):
    """Fit the model with early‑stopping & checkpointing."""
    print('\nTraining started at:',
          datetime.now().strftime('%d/%m/%Y %H:%M:%S'), '\n')

    early_stop = keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=EARLY_STOP_PATIENCE
    )
    callbacks = [
        PrintBestEpoch(),
        early_stop,
        keras.callbacks.ModelCheckpoint(
            filepath=weights_path,
            monitor='val_loss',
            save_best_only=True,
            verbose=0
        )
    ]

    history = model.fit(
        train_X,
        train_y_onehot,
        epochs=EPOCHS,
        validation_split=VAL_SPLIT,
        batch_size=BATCH_SIZE,
        verbose=1,
        callbacks=callbacks
    )

    # Save the final model (architecture + weights)
    model.save(model_path)
    return model, history


#%% ---------------------------------------------------------------------------
# Evaluation helper (binary) – uses scikit‑learn
# ---------------------------------------------------------------------------
def evaluate_binary(model_path, test_X, test_y):
    """
    Load a saved model, predict on test data and return a dict with
    accuracy, precision, recall and F1‑score (computed by scikit‑learn).
    """
    model = keras.models.load_model(model_path)
    pred_prob = model.predict(test_X)                     # shape (N, 2)
    pred_class = np.argmax(pred_prob, axis=1)            # 0 or 1

    y_true = test_y.ravel().astype(int)

    acc  = accuracy_score(y_true, pred_class)
    prec = precision_score(y_true, pred_class, zero_division=0)
    rec  = recall_score(y_true, pred_class, zero_division=0)
    f1   = f1_score(y_true, pred_class, zero_division=0)

    summary = {
        "Accuracy":   np.round(acc,   3),
        "Precision": np.round(prec,  3),
        "Recall":    np.round(rec,   3),
        "F1‑Score":  np.round(f1,    3)
    }
    return summary


#%% ---------------------------------------------------------------------------
# Simple container for the two data‑sets
# ---------------------------------------------------------------------------
class DatasetInfo:
    """Holds file locations and a short identifier for a data‑set."""
    def __init__(self, name, data_path, label_path):
        self.name = name                # e.g. 'siesta' or 'esada'
        self.data_path = data_path
        self.label_path = label_path


# Define the two data‑sets (adjust paths if you move the script)
DATASETS = [
    DatasetInfo(
        name='siesta',
        data_path='SIESTA_4percent/DataMatrix_SpO2_cleaned4_.txt',
        label_path='SIESTA_4percent/BinaryOutput_SpO2_cleaned4_.txt'
    ),
    DatasetInfo(
        name='esada',
        data_path='ESADA_4percent/DataMatrix_SpO2_cleaned4__esada.txt',
        label_path='ESADA_4percent/BinaryOutput_SpO2_cleaned4__esada.txt'
    )
]


#%% ---------------------------------------------------------------------------
# Main driver – run the whole pipeline for each data‑set
# ---------------------------------------------------------------------------
def run_for_dataset(ds: DatasetInfo, test_fraction=0.1):
    """Load data, train binary model, evaluate and return the metric dict."""
    print('\n' + '=' * 70)
    print(f'Processing data‑set: {ds.name.upper()}')
    print('=' * 70)

    # ---- Load --------------------------------------------------------------
    X = np.loadtxt(ds.data_path, delimiter=',')
    y = np.expand_dims(np.loadtxt(ds.label_path), axis=1)

    # ---- Train / test split -------------------------------------------------
    n_samples = X.shape[0]                     # total number of samples
    n_test = int(round(test_fraction * n_samples))

    indices = np.random.permutation(n_samples)
    test_idx = indices[:n_test]
    train_idx = indices[n_test:]

    X_train, X_test = X[train_idx, :], X[test_idx, :]
    y_train, y_test = y[train_idx], y[test_idx]

    # One‑hot encode the binary labels for training
    y_train_oh = keras.utils.to_categorical(y_train, NUM_CLASSES)

    # ---- Build, train and save ------------------------------------------------
    model = build_binary_model()
    model_path   = f'{ds.name}_ml_binary.keras'   # final model
    weights_path = f'{ds.name}_wg_binary.keras'   # best‑epoch checkpoint

    model, _ = train_model(
        model,
        X_train,
        y_train_oh,
        model_path,
        weights_path
    )

    # ---- Evaluate -----------------------------------------------------------
    summary = evaluate_binary(model_path, X_test, y_test)

    # Add fields needed for the DataFrame
    summary["Dataset"] = ds.name.upper()
    summary["Samples"] = n_samples

    print(f'\nDesaturation binary model – {ds.name.upper()}')
    print(summary)

    return summary


#%% ---------------------------------------------------------------------------
# Execute for every defined data‑set and store the results in a DataFrame
# ---------------------------------------------------------------------------
if __name__ == '__main__':
    # Collect a dict for each data‑set
    results_list = []

    for ds in DATASETS:
        results_list.append(run_for_dataset(ds, test_fraction=0.1))

    # Convert the list of dicts into a pandas DataFrame
    results_df = pd.DataFrame(results_list)

    # Order columns for a tidy display
    results_df = results_df[
        ['Dataset', 'Samples', 'Accuracy', 'Precision', 'Recall', 'F1‑Score']
    ]

    # Show the DataFrame
    print("\n=== Summary of all data‑sets (pandas DataFrame) ===")
    print(results_df)

    # -----------------------------------------------------------------------
    # The DataFrame `results_df` can now be reused:
    #   results_df.to_csv('desat_metrics.csv', index=False)
    #   results_df.plot(kind='bar', x='Dataset')
    # -----------------------------------------------------------------------
# Out:
# 2025-08-13 15:58:42.351913: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-13 15:58:42.362040: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-13 15:58:42.371354: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-13 15:58:42.396167: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755093522.437544 1926865 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755093522.449696 1926865 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755093522.480670 1926865 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755093522.480711 1926865 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755093522.480716 1926865 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755093522.480719 1926865 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-13 15:58:42.491328: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ======================================================================
# Processing data‑set: SIESTA
# ======================================================================
# /home/bowden/Code/HARPOCRATES/demonstator/Privacy-Preserving-ML-through-HHE/env/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-08-13 15:58:49.776778: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 30)             │         9,030 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           310 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            22 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,362 (36.57 KB)
#  Trainable params: 9,362 (36.57 KB)
#  Non-trainable params: 0 (0.00 B)
# Training started at: 13/08/2025 15:58:50
#
# Epoch 1/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 480ms/step - accuracy: 0.7817 - loss: 0.1922 - val_accuracy: 0.7673 - val_loss: 0.1961
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7818 - loss: 0.1850 - val_accuracy: 0.7673 - val_loss: 0.1927
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.7818 - loss: 0.1819 - val_accuracy: 0.7673 - val_loss: 0.1904
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7818 - loss: 0.1795 - val_accuracy: 0.7677 - val_loss: 0.1865
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.7818 - loss: 0.1753 - val_accuracy: 0.7677 - val_loss: 0.1804
# Epoch 6/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7819 - loss: 0.1700 - val_accuracy: 0.7682 - val_loss: 0.1804
# Epoch 7/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7821 - loss: 0.1721 - val_accuracy: 0.7682 - val_loss: 0.1689
# Epoch 8/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.7829 - loss: 0.1599 - val_accuracy: 0.7695 - val_loss: 0.1618
# Epoch 9/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7840 - loss: 0.1540 - val_accuracy: 0.7700 - val_loss: 0.1617
# Epoch 10/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.7849 - loss: 0.1541 - val_accuracy: 0.7704 - val_loss: 0.1619
# Epoch 11/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.7858 - loss: 0.1531 - val_accuracy: 0.7713 - val_loss: 0.1594
# Epoch 12/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7885 - loss: 0.1513 - val_accuracy: 0.7775 - val_loss: 0.1582
# Epoch 13/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7938 - loss: 0.1525 - val_accuracy: 0.7735 - val_loss: 0.1573
# Epoch 14/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7903 - loss: 0.1495 - val_accuracy: 0.7731 - val_loss: 0.1589
# Epoch 15/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7898 - loss: 0.1507 - val_accuracy: 0.7744 - val_loss: 0.1578
# Epoch 16/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7909 - loss: 0.1500 - val_accuracy: 0.7775 - val_loss: 0.1547
# Epoch 17/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7931 - loss: 0.1469 - val_accuracy: 0.7860 - val_loss: 0.1510
# Epoch 18/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7985 - loss: 0.1441 - val_accuracy: 0.7851 - val_loss: 0.1518
# Epoch 19/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.7992 - loss: 0.1447 - val_accuracy: 0.7815 - val_loss: 0.1529
# Epoch 20/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7971 - loss: 0.1448 - val_accuracy: 0.7829 - val_loss: 0.1509
# Epoch 21/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7998 - loss: 0.1432 - val_accuracy: 0.7896 - val_loss: 0.1500
# Epoch 22/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8029 - loss: 0.1434 - val_accuracy: 0.7909 - val_loss: 0.1469
# Epoch 23/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8045 - loss: 0.1405 - val_accuracy: 0.7864 - val_loss: 0.1474
# Epoch 24/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8016 - loss: 0.1398 - val_accuracy: 0.7864 - val_loss: 0.1486
# Epoch 25/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8010 - loss: 0.1406 - val_accuracy: 0.7873 - val_loss: 0.1480
# Epoch 26/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8020 - loss: 0.1400 - val_accuracy: 0.7914 - val_loss: 0.1466
# Epoch 27/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8038 - loss: 0.1391 - val_accuracy: 0.7896 - val_loss: 0.1464
# Epoch 28/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8053 - loss: 0.1388 - val_accuracy: 0.7891 - val_loss: 0.1459
# Epoch 29/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8050 - loss: 0.1384 - val_accuracy: 0.7909 - val_loss: 0.1487
# Epoch 30/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8072 - loss: 0.1424 - val_accuracy: 0.7851 - val_loss: 0.1466
# Epoch 31/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8007 - loss: 0.1386 - val_accuracy: 0.7838 - val_loss: 0.1496
# Epoch 32/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.7986 - loss: 0.1412 - val_accuracy: 0.7900 - val_loss: 0.1464
# Epoch 33/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8045 - loss: 0.1394 - val_accuracy: 0.7922 - val_loss: 0.1445
# Epoch 34/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8064 - loss: 0.1376 - val_accuracy: 0.7869 - val_loss: 0.1453
# Epoch 35/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8035 - loss: 0.1375 - val_accuracy: 0.7882 - val_loss: 0.1480
# Epoch 36/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8039 - loss: 0.1403 - val_accuracy: 0.7869 - val_loss: 0.1478
# Epoch 37/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8029 - loss: 0.1399 - val_accuracy: 0.7842 - val_loss: 0.1465
# Epoch 38/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.8011 - loss: 0.1382 - val_accuracy: 0.7927 - val_loss: 0.1440
# Epoch 39/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8071 - loss: 0.1368 - val_accuracy: 0.8052 - val_loss: 0.1431
# Epoch 40/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8153 - loss: 0.1374 - val_accuracy: 0.8038 - val_loss: 0.1436
# Epoch 41/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8134 - loss: 0.1368 - val_accuracy: 0.8052 - val_loss: 0.1463
# Epoch 42/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8145 - loss: 0.1394 - val_accuracy: 0.8016 - val_loss: 0.1434
# Epoch 43/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8135 - loss: 0.1364 - val_accuracy: 0.8021 - val_loss: 0.1411
# Epoch 44/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8134 - loss: 0.1347 - val_accuracy: 0.8038 - val_loss: 0.1424
# Epoch 45/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8138 - loss: 0.1362 - val_accuracy: 0.7994 - val_loss: 0.1435
# Epoch 46/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8100 - loss: 0.1360 - val_accuracy: 0.7931 - val_loss: 0.1451
# Epoch 47/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8060 - loss: 0.1368 - val_accuracy: 0.7922 - val_loss: 0.1452
# Epoch 48/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8053 - loss: 0.1369 - val_accuracy: 0.7936 - val_loss: 0.1441
# Epoch 49/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8077 - loss: 0.1364 - val_accuracy: 0.7954 - val_loss: 0.1431
# Epoch 50/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8085 - loss: 0.1355 - val_accuracy: 0.8021 - val_loss: 0.1420
# Epoch 51/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8147 - loss: 0.1348 - val_accuracy: 0.8145 - val_loss: 0.1453
# Epoch 52/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8220 - loss: 0.1403 - val_accuracy: 0.8052 - val_loss: 0.1405
# Epoch 53/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8149 - loss: 0.1339 - val_accuracy: 0.7985 - val_loss: 0.1432
# Epoch 54/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8078 - loss: 0.1352 - val_accuracy: 0.7998 - val_loss: 0.1430
# Epoch 55/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8100 - loss: 0.1353 - val_accuracy: 0.8047 - val_loss: 0.1419
# Epoch 56/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8158 - loss: 0.1350 - val_accuracy: 0.8012 - val_loss: 0.1418
# Epoch 57/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8121 - loss: 0.1342 - val_accuracy: 0.7954 - val_loss: 0.1441
# Epoch 58/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8072 - loss: 0.1357 - val_accuracy: 0.8003 - val_loss: 0.1435
# Epoch 59/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8122 - loss: 0.1349 - val_accuracy: 0.8021 - val_loss: 0.1418
# Epoch 60/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8161 - loss: 0.1336 - val_accuracy: 0.8056 - val_loss: 0.1403
# Epoch 61/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8160 - loss: 0.1327 - val_accuracy: 0.8043 - val_loss: 0.1394
# Epoch 62/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8149 - loss: 0.1326 - val_accuracy: 0.8025 - val_loss: 0.1400
# Epoch 63/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8125 - loss: 0.1335 - val_accuracy: 0.8074 - val_loss: 0.1393
# Epoch 64/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8167 - loss: 0.1334 - val_accuracy: 0.8128 - val_loss: 0.1393
# Epoch 65/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8230 - loss: 0.1336 - val_accuracy: 0.8038 - val_loss: 0.1395
# Epoch 66/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8153 - loss: 0.1318 - val_accuracy: 0.7994 - val_loss: 0.1437
# Epoch 67/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8099 - loss: 0.1349 - val_accuracy: 0.8016 - val_loss: 0.1441
# Epoch 68/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8127 - loss: 0.1354 - val_accuracy: 0.8052 - val_loss: 0.1432
# Epoch 69/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8192 - loss: 0.1351 - val_accuracy: 0.8025 - val_loss: 0.1421
# Epoch 70/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8135 - loss: 0.1335 - val_accuracy: 0.8007 - val_loss: 0.1412
# Epoch 71/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8119 - loss: 0.1332 - val_accuracy: 0.8181 - val_loss: 0.1431
# Epoch 72/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8258 - loss: 0.1380 - val_accuracy: 0.8056 - val_loss: 0.1377
# Epoch 73/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8183 - loss: 0.1308 - val_accuracy: 0.8021 - val_loss: 0.1422
# Epoch 74/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8117 - loss: 0.1336 - val_accuracy: 0.8074 - val_loss: 0.1445
# Epoch 75/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8182 - loss: 0.1364 - val_accuracy: 0.8047 - val_loss: 0.1429
# Epoch 76/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8150 - loss: 0.1339 - val_accuracy: 0.7989 - val_loss: 0.1440
# Epoch 77/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8090 - loss: 0.1347 - val_accuracy: 0.8029 - val_loss: 0.1407
# Epoch 78/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8138 - loss: 0.1327 - val_accuracy: 0.8128 - val_loss: 0.1413
# Epoch 79/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8214 - loss: 0.1350 - val_accuracy: 0.8074 - val_loss: 0.1375
# Epoch 80/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8170 - loss: 0.1301 - val_accuracy: 0.8070 - val_loss: 0.1379
# Epoch 81/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8190 - loss: 0.1303 - val_accuracy: 0.8194 - val_loss: 0.1410
# Epoch 82/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8284 - loss: 0.1351 - val_accuracy: 0.8168 - val_loss: 0.1358
# Epoch 83/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8249 - loss: 0.1292 - val_accuracy: 0.8119 - val_loss: 0.1360
# Epoch 84/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8213 - loss: 0.1294 - val_accuracy: 0.8123 - val_loss: 0.1371
# Epoch 85/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8192 - loss: 0.1303 - val_accuracy: 0.8145 - val_loss: 0.1364
# Epoch 86/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8228 - loss: 0.1297 - val_accuracy: 0.8145 - val_loss: 0.1363
# Epoch 87/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8223 - loss: 0.1287 - val_accuracy: 0.8101 - val_loss: 0.1385
# Epoch 88/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8216 - loss: 0.1302 - val_accuracy: 0.8087 - val_loss: 0.1376
# Epoch 89/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8208 - loss: 0.1295 - val_accuracy: 0.8163 - val_loss: 0.1357
# Epoch 90/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8250 - loss: 0.1289 - val_accuracy: 0.8235 - val_loss: 0.1371
# Epoch 91/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8306 - loss: 0.1312 - val_accuracy: 0.8150 - val_loss: 0.1351
# Epoch 92/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8231 - loss: 0.1278 - val_accuracy: 0.8119 - val_loss: 0.1380
# Epoch 93/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8212 - loss: 0.1304 - val_accuracy: 0.8078 - val_loss: 0.1382
# Epoch 94/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8194 - loss: 0.1298 - val_accuracy: 0.8110 - val_loss: 0.1377
# Epoch 95/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8226 - loss: 0.1291 - val_accuracy: 0.8136 - val_loss: 0.1362
# Epoch 96/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8255 - loss: 0.1278 - val_accuracy: 0.8168 - val_loss: 0.1343
# Epoch 97/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8267 - loss: 0.1267 - val_accuracy: 0.8279 - val_loss: 0.1342
# Epoch 98/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8321 - loss: 0.1288 - val_accuracy: 0.8159 - val_loss: 0.1334
# Epoch 99/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8250 - loss: 0.1269 - val_accuracy: 0.8087 - val_loss: 0.1369
# Epoch 100/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8193 - loss: 0.1286 - val_accuracy: 0.8123 - val_loss: 0.1353
# Epoch 101/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8233 - loss: 0.1274 - val_accuracy: 0.8248 - val_loss: 0.1358
# Epoch 102/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8346 - loss: 0.1297 - val_accuracy: 0.8185 - val_loss: 0.1331
# Epoch 103/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8315 - loss: 0.1259 - val_accuracy: 0.8150 - val_loss: 0.1358
# Epoch 104/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8248 - loss: 0.1277 - val_accuracy: 0.8181 - val_loss: 0.1358
# Epoch 105/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8256 - loss: 0.1279 - val_accuracy: 0.8208 - val_loss: 0.1330
# Epoch 106/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8287 - loss: 0.1259 - val_accuracy: 0.8194 - val_loss: 0.1330
# Epoch 107/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8265 - loss: 0.1261 - val_accuracy: 0.8159 - val_loss: 0.1347
# Epoch 108/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8255 - loss: 0.1275 - val_accuracy: 0.8150 - val_loss: 0.1328
# Epoch 109/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8285 - loss: 0.1252 - val_accuracy: 0.8239 - val_loss: 0.1314
# Epoch 110/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8343 - loss: 0.1244 - val_accuracy: 0.8123 - val_loss: 0.1344
# Epoch 111/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8250 - loss: 0.1259 - val_accuracy: 0.8034 - val_loss: 0.1411
# Epoch 112/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8147 - loss: 0.1314 - val_accuracy: 0.8070 - val_loss: 0.1383
# Epoch 113/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8190 - loss: 0.1291 - val_accuracy: 0.8217 - val_loss: 0.1370
# Epoch 114/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8359 - loss: 0.1298 - val_accuracy: 0.8208 - val_loss: 0.1321
# Epoch 115/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8316 - loss: 0.1243 - val_accuracy: 0.8096 - val_loss: 0.1359
# Epoch 116/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8233 - loss: 0.1275 - val_accuracy: 0.8114 - val_loss: 0.1352
# Epoch 117/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8254 - loss: 0.1268 - val_accuracy: 0.8181 - val_loss: 0.1321
# Epoch 118/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8301 - loss: 0.1242 - val_accuracy: 0.8145 - val_loss: 0.1320
# Epoch 119/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8263 - loss: 0.1236 - val_accuracy: 0.8163 - val_loss: 0.1326
# Epoch 120/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8268 - loss: 0.1245 - val_accuracy: 0.8203 - val_loss: 0.1320
# Epoch 121/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8332 - loss: 0.1245 - val_accuracy: 0.8257 - val_loss: 0.1293
# Epoch 122/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8352 - loss: 0.1223 - val_accuracy: 0.8212 - val_loss: 0.1311
# Epoch 123/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8328 - loss: 0.1240 - val_accuracy: 0.8128 - val_loss: 0.1338
# Epoch 124/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8258 - loss: 0.1257 - val_accuracy: 0.8114 - val_loss: 0.1353
# Epoch 125/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8257 - loss: 0.1263 - val_accuracy: 0.8226 - val_loss: 0.1341
# Epoch 126/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8379 - loss: 0.1266 - val_accuracy: 0.8288 - val_loss: 0.1291
# Epoch 127/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8381 - loss: 0.1219 - val_accuracy: 0.8203 - val_loss: 0.1291
# Epoch 128/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8322 - loss: 0.1218 - val_accuracy: 0.8270 - val_loss: 0.1338
# Epoch 129/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8369 - loss: 0.1280 - val_accuracy: 0.8172 - val_loss: 0.1317
# Epoch 130/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8267 - loss: 0.1233 - val_accuracy: 0.8199 - val_loss: 0.1324
# Epoch 131/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8314 - loss: 0.1241 - val_accuracy: 0.8230 - val_loss: 0.1300
# Epoch 132/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8342 - loss: 0.1224 - val_accuracy: 0.8203 - val_loss: 0.1307
# Epoch 133/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8332 - loss: 0.1241 - val_accuracy: 0.8270 - val_loss: 0.1314
# Epoch 134/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8377 - loss: 0.1259 - val_accuracy: 0.8150 - val_loss: 0.1296
# Epoch 135/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.8305 - loss: 0.1220 - val_accuracy: 0.8226 - val_loss: 0.1282
# Epoch 136/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8349 - loss: 0.1203 - val_accuracy: 0.8275 - val_loss: 0.1284
# Epoch 137/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8403 - loss: 0.1203 - val_accuracy: 0.8221 - val_loss: 0.1292
# Epoch 138/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.8348 - loss: 0.1207 - val_accuracy: 0.8377 - val_loss: 0.1265
# Epoch 139/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8449 - loss: 0.1201 - val_accuracy: 0.8368 - val_loss: 0.1247
# Epoch 140/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8477 - loss: 0.1185 - val_accuracy: 0.8239 - val_loss: 0.1272
# Epoch 141/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8377 - loss: 0.1191 - val_accuracy: 0.8181 - val_loss: 0.1292
# Epoch 142/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8345 - loss: 0.1201 - val_accuracy: 0.8226 - val_loss: 0.1282
# Epoch 143/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8389 - loss: 0.1192 - val_accuracy: 0.8266 - val_loss: 0.1273
# Epoch 144/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8426 - loss: 0.1188 - val_accuracy: 0.8221 - val_loss: 0.1271
# Epoch 145/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8374 - loss: 0.1185 - val_accuracy: 0.8261 - val_loss: 0.1255
# Epoch 146/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8416 - loss: 0.1178 - val_accuracy: 0.8306 - val_loss: 0.1253
# Epoch 147/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8455 - loss: 0.1181 - val_accuracy: 0.8337 - val_loss: 0.1254
# Epoch 148/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8469 - loss: 0.1177 - val_accuracy: 0.8333 - val_loss: 0.1259
# Epoch 149/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8451 - loss: 0.1179 - val_accuracy: 0.8279 - val_loss: 0.1253
# Epoch 150/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8411 - loss: 0.1172 - val_accuracy: 0.8368 - val_loss: 0.1268
# Epoch 151/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8463 - loss: 0.1213 - val_accuracy: 0.8310 - val_loss: 0.1242
# Epoch 152/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8419 - loss: 0.1174 - val_accuracy: 0.8154 - val_loss: 0.1303
# Epoch 153/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8307 - loss: 0.1209 - val_accuracy: 0.8248 - val_loss: 0.1283
# Epoch 154/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8373 - loss: 0.1192 - val_accuracy: 0.8284 - val_loss: 0.1264
# Epoch 155/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8451 - loss: 0.1185 - val_accuracy: 0.8284 - val_loss: 0.1238
# Epoch 156/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8442 - loss: 0.1160 - val_accuracy: 0.8373 - val_loss: 0.1261
# Epoch 157/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8480 - loss: 0.1197 - val_accuracy: 0.8373 - val_loss: 0.1237
# Epoch 158/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8477 - loss: 0.1169 - val_accuracy: 0.8391 - val_loss: 0.1235
# Epoch 159/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.8507 - loss: 0.1175 - val_accuracy: 0.8235 - val_loss: 0.1264
# Epoch 160/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8395 - loss: 0.1178 - val_accuracy: 0.8163 - val_loss: 0.1305
# Epoch 161/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8329 - loss: 0.1207 - val_accuracy: 0.8333 - val_loss: 0.1320
# Epoch 162/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8476 - loss: 0.1255 - val_accuracy: 0.8337 - val_loss: 0.1248
# Epoch 163/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8473 - loss: 0.1171 - val_accuracy: 0.8292 - val_loss: 0.1251
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8423 - loss: 0.1174 - val_accuracy: 0.8292 - val_loss: 0.1262
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8393 - loss: 0.1191 - val_accuracy: 0.8292 - val_loss: 0.1267
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8364 - loss: 0.1199 - val_accuracy: 0.8288 - val_loss: 0.1260
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8387 - loss: 0.1194 - val_accuracy: 0.8301 - val_loss: 0.1277
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8422 - loss: 0.1210 - val_accuracy: 0.8208 - val_loss: 0.1283
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8326 - loss: 0.1197 - val_accuracy: 0.8306 - val_loss: 0.1247
# Epoch 170/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8456 - loss: 0.1160 - val_accuracy: 0.8337 - val_loss: 0.1258
# Epoch 171/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8538 - loss: 0.1180 - val_accuracy: 0.8243 - val_loss: 0.1252
# Epoch 172/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8414 - loss: 0.1163 - val_accuracy: 0.8261 - val_loss: 0.1251
# Epoch 173/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.8414 - loss: 0.1173 - val_accuracy: 0.8257 - val_loss: 0.1246
# Epoch 174/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8409 - loss: 0.1174 - val_accuracy: 0.8364 - val_loss: 0.1246
# Epoch 175/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8459 - loss: 0.1188 - val_accuracy: 0.8172 - val_loss: 0.1285
# Epoch 176/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8323 - loss: 0.1196 - val_accuracy: 0.8136 - val_loss: 0.1320
# Epoch 177/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8315 - loss: 0.1212 - val_accuracy: 0.8315 - val_loss: 0.1352
# Epoch 178/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8469 - loss: 0.1280 - val_accuracy: 0.8292 - val_loss: 0.1241
# Epoch 179/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.8439 - loss: 0.1156 - val_accuracy: 0.8449 - val_loss: 0.1224
# Epoch 180/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8527 - loss: 0.1167 - val_accuracy: 0.8315 - val_loss: 0.1237
# Epoch 181/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8433 - loss: 0.1163 - val_accuracy: 0.8203 - val_loss: 0.1285
# Epoch 182/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8332 - loss: 0.1196 - val_accuracy: 0.8292 - val_loss: 0.1252
# Epoch 183/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8437 - loss: 0.1171 - val_accuracy: 0.8342 - val_loss: 0.1228
# Epoch 184/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8479 - loss: 0.1150 - val_accuracy: 0.8382 - val_loss: 0.1215
# Epoch 185/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8514 - loss: 0.1142 - val_accuracy: 0.8404 - val_loss: 0.1232
# Epoch 186/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8518 - loss: 0.1170 - val_accuracy: 0.8382 - val_loss: 0.1224
# Epoch 187/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8485 - loss: 0.1154 - val_accuracy: 0.8426 - val_loss: 0.1209
# Epoch 188/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8509 - loss: 0.1137 - val_accuracy: 0.8417 - val_loss: 0.1209
# Epoch 189/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8510 - loss: 0.1131 - val_accuracy: 0.8426 - val_loss: 0.1214
# Epoch 190/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8556 - loss: 0.1143 - val_accuracy: 0.8404 - val_loss: 0.1205
# Epoch 191/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8560 - loss: 0.1135 - val_accuracy: 0.8373 - val_loss: 0.1208
# Epoch 192/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8496 - loss: 0.1128 - val_accuracy: 0.8399 - val_loss: 0.1211
# Epoch 193/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8510 - loss: 0.1138 - val_accuracy: 0.8386 - val_loss: 0.1210
# Epoch 194/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8497 - loss: 0.1134 - val_accuracy: 0.8386 - val_loss: 0.1204
# Epoch 195/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8524 - loss: 0.1127 - val_accuracy: 0.8493 - val_loss: 0.1205
# Epoch 196/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8578 - loss: 0.1140 - val_accuracy: 0.8431 - val_loss: 0.1204
# Epoch 197/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8570 - loss: 0.1135 - val_accuracy: 0.8337 - val_loss: 0.1217
# Epoch 198/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8479 - loss: 0.1127 - val_accuracy: 0.8342 - val_loss: 0.1235
# Epoch 199/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8469 - loss: 0.1138 - val_accuracy: 0.8359 - val_loss: 0.1221
# Epoch 200/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8512 - loss: 0.1133 - val_accuracy: 0.8373 - val_loss: 0.1214
# Epoch 201/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8559 - loss: 0.1136 - val_accuracy: 0.8408 - val_loss: 0.1234
# Epoch 202/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8572 - loss: 0.1164 - val_accuracy: 0.8337 - val_loss: 0.1210
# Epoch 203/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8503 - loss: 0.1121 - val_accuracy: 0.8252 - val_loss: 0.1245
# Epoch 204/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8422 - loss: 0.1152 - val_accuracy: 0.8364 - val_loss: 0.1209
# Epoch 205/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8485 - loss: 0.1130 - val_accuracy: 0.8462 - val_loss: 0.1202
# Epoch 206/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8562 - loss: 0.1143 - val_accuracy: 0.8408 - val_loss: 0.1193
# Epoch 207/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8509 - loss: 0.1112 - val_accuracy: 0.8359 - val_loss: 0.1207
# Epoch 208/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8490 - loss: 0.1120 - val_accuracy: 0.8399 - val_loss: 0.1219
# Epoch 209/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8569 - loss: 0.1145 - val_accuracy: 0.8395 - val_loss: 0.1185
# Epoch 210/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8550 - loss: 0.1100 - val_accuracy: 0.8422 - val_loss: 0.1214
# Epoch 211/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8549 - loss: 0.1139 - val_accuracy: 0.8346 - val_loss: 0.1211
# Epoch 212/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8503 - loss: 0.1121 - val_accuracy: 0.8386 - val_loss: 0.1210
# Epoch 213/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8508 - loss: 0.1123 - val_accuracy: 0.8462 - val_loss: 0.1194
# Epoch 214/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8547 - loss: 0.1123 - val_accuracy: 0.8462 - val_loss: 0.1183
# Epoch 215/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8544 - loss: 0.1114 - val_accuracy: 0.8386 - val_loss: 0.1195
# Epoch 216/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8519 - loss: 0.1112 - val_accuracy: 0.8359 - val_loss: 0.1197
# Epoch 217/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8534 - loss: 0.1109 - val_accuracy: 0.8444 - val_loss: 0.1237
# Epoch 218/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8585 - loss: 0.1175 - val_accuracy: 0.8377 - val_loss: 0.1187
# Epoch 219/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8526 - loss: 0.1099 - val_accuracy: 0.8422 - val_loss: 0.1196
# Epoch 220/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8537 - loss: 0.1116 - val_accuracy: 0.8382 - val_loss: 0.1198
# Epoch 221/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8506 - loss: 0.1119 - val_accuracy: 0.8279 - val_loss: 0.1239
# Epoch 222/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8419 - loss: 0.1154 - val_accuracy: 0.8382 - val_loss: 0.1209
# Epoch 223/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8533 - loss: 0.1145 - val_accuracy: 0.8435 - val_loss: 0.1175
# Epoch 224/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8559 - loss: 0.1111 - val_accuracy: 0.8297 - val_loss: 0.1222
# Epoch 225/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8442 - loss: 0.1132 - val_accuracy: 0.8328 - val_loss: 0.1220
# Epoch 226/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8490 - loss: 0.1135 - val_accuracy: 0.8355 - val_loss: 0.1221
# Epoch 227/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8530 - loss: 0.1140 - val_accuracy: 0.8270 - val_loss: 0.1250
# Epoch 228/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8421 - loss: 0.1149 - val_accuracy: 0.8284 - val_loss: 0.1234
# Epoch 229/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8429 - loss: 0.1136 - val_accuracy: 0.8480 - val_loss: 0.1189
# Epoch 230/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8585 - loss: 0.1121 - val_accuracy: 0.8377 - val_loss: 0.1184
# Epoch 231/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8528 - loss: 0.1103 - val_accuracy: 0.8328 - val_loss: 0.1210
# Epoch 232/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8472 - loss: 0.1128 - val_accuracy: 0.8471 - val_loss: 0.1185
# Epoch 233/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8550 - loss: 0.1117 - val_accuracy: 0.8386 - val_loss: 0.1198
# Epoch 234/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8517 - loss: 0.1114 - val_accuracy: 0.8324 - val_loss: 0.1237
# Epoch 235/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8462 - loss: 0.1143 - val_accuracy: 0.8395 - val_loss: 0.1252
# Epoch 236/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8532 - loss: 0.1174 - val_accuracy: 0.8399 - val_loss: 0.1197
# Epoch 237/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8518 - loss: 0.1108 - val_accuracy: 0.8404 - val_loss: 0.1180
# Epoch 238/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8526 - loss: 0.1099 - val_accuracy: 0.8440 - val_loss: 0.1181
# Epoch 239/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8562 - loss: 0.1117 - val_accuracy: 0.8373 - val_loss: 0.1175
# Epoch 240/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8523 - loss: 0.1097 - val_accuracy: 0.8480 - val_loss: 0.1171
# Epoch 241/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8600 - loss: 0.1099 - val_accuracy: 0.8449 - val_loss: 0.1179
# Epoch 242/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8587 - loss: 0.1099 - val_accuracy: 0.8435 - val_loss: 0.1172
# Epoch 243/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8586 - loss: 0.1083 - val_accuracy: 0.8404 - val_loss: 0.1175
# Epoch 244/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8587 - loss: 0.1083 - val_accuracy: 0.8413 - val_loss: 0.1174
# Epoch 245/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8543 - loss: 0.1081 - val_accuracy: 0.8515 - val_loss: 0.1146
# Epoch 246/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8612 - loss: 0.1077 - val_accuracy: 0.8520 - val_loss: 0.1144
# Epoch 247/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8629 - loss: 0.1078 - val_accuracy: 0.8417 - val_loss: 0.1155
# Epoch 248/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8593 - loss: 0.1068 - val_accuracy: 0.8391 - val_loss: 0.1186
# Epoch 249/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8572 - loss: 0.1088 - val_accuracy: 0.8359 - val_loss: 0.1204
# Epoch 250/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8549 - loss: 0.1099 - val_accuracy: 0.8342 - val_loss: 0.1203
# Epoch 251/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8513 - loss: 0.1101 - val_accuracy: 0.8395 - val_loss: 0.1180
# Epoch 252/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8571 - loss: 0.1092 - val_accuracy: 0.8493 - val_loss: 0.1156
# Epoch 253/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8625 - loss: 0.1081 - val_accuracy: 0.8408 - val_loss: 0.1171
# Epoch 254/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8541 - loss: 0.1086 - val_accuracy: 0.8346 - val_loss: 0.1203
# Epoch 255/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8487 - loss: 0.1111 - val_accuracy: 0.8391 - val_loss: 0.1189
# Epoch 256/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8542 - loss: 0.1097 - val_accuracy: 0.8466 - val_loss: 0.1164
# Epoch 257/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8590 - loss: 0.1077 - val_accuracy: 0.8466 - val_loss: 0.1160
# Epoch 258/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8582 - loss: 0.1069 - val_accuracy: 0.8453 - val_loss: 0.1180
# Epoch 259/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8564 - loss: 0.1099 - val_accuracy: 0.8435 - val_loss: 0.1181
# Epoch 260/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8554 - loss: 0.1101 - val_accuracy: 0.8484 - val_loss: 0.1178
# Epoch 261/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8618 - loss: 0.1101 - val_accuracy: 0.8342 - val_loss: 0.1192
# Epoch 262/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8516 - loss: 0.1093 - val_accuracy: 0.8346 - val_loss: 0.1227
# Epoch 263/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8489 - loss: 0.1128 - val_accuracy: 0.8399 - val_loss: 0.1225
# Epoch 264/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8531 - loss: 0.1143 - val_accuracy: 0.8292 - val_loss: 0.1254
# Epoch 265/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8422 - loss: 0.1151 - val_accuracy: 0.8328 - val_loss: 0.1243
# Epoch 266/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8438 - loss: 0.1145 - val_accuracy: 0.8471 - val_loss: 0.1186
# Epoch 267/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8602 - loss: 0.1122 - val_accuracy: 0.8417 - val_loss: 0.1168
# Epoch 268/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8550 - loss: 0.1088 - val_accuracy: 0.8333 - val_loss: 0.1212
# Epoch 269/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8488 - loss: 0.1112 - val_accuracy: 0.8413 - val_loss: 0.1266
# Epoch 270/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8566 - loss: 0.1194 - val_accuracy: 0.8350 - val_loss: 0.1189
# Epoch 271/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8521 - loss: 0.1098 - val_accuracy: 0.8404 - val_loss: 0.1189
# Epoch 272/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8542 - loss: 0.1107 - val_accuracy: 0.8431 - val_loss: 0.1170
# Epoch 273/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8538 - loss: 0.1084 - val_accuracy: 0.8404 - val_loss: 0.1198
# Epoch 274/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8515 - loss: 0.1123 - val_accuracy: 0.8386 - val_loss: 0.1202
# Epoch 275/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8500 - loss: 0.1121 - val_accuracy: 0.8373 - val_loss: 0.1214
# Epoch 276/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8470 - loss: 0.1125 - val_accuracy: 0.8453 - val_loss: 0.1180
# Epoch 277/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8585 - loss: 0.1105 - val_accuracy: 0.8484 - val_loss: 0.1162
# Epoch 278/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8608 - loss: 0.1087 - val_accuracy: 0.8431 - val_loss: 0.1178
# Epoch 279/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8562 - loss: 0.1089 - val_accuracy: 0.8377 - val_loss: 0.1188
# Epoch 280/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8537 - loss: 0.1094 - val_accuracy: 0.8453 - val_loss: 0.1174
# Epoch 281/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8596 - loss: 0.1087 - val_accuracy: 0.8489 - val_loss: 0.1162
# Epoch 282/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8595 - loss: 0.1078 - val_accuracy: 0.8511 - val_loss: 0.1161
# Epoch 283/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8603 - loss: 0.1093 - val_accuracy: 0.8524 - val_loss: 0.1132
# Epoch 284/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8640 - loss: 0.1072 - val_accuracy: 0.8502 - val_loss: 0.1133
# Epoch 285/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8603 - loss: 0.1055 - val_accuracy: 0.8511 - val_loss: 0.1149
# Epoch 286/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8586 - loss: 0.1067 - val_accuracy: 0.8515 - val_loss: 0.1146
# Epoch 287/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8615 - loss: 0.1070 - val_accuracy: 0.8489 - val_loss: 0.1122
# Epoch 288/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8647 - loss: 0.1041 - val_accuracy: 0.8515 - val_loss: 0.1144
# Epoch 289/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8637 - loss: 0.1068 - val_accuracy: 0.8453 - val_loss: 0.1145
# Epoch 290/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8596 - loss: 0.1057 - val_accuracy: 0.8502 - val_loss: 0.1141
# Epoch 291/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8650 - loss: 0.1061 - val_accuracy: 0.8533 - val_loss: 0.1132
# Epoch 292/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8650 - loss: 0.1060 - val_accuracy: 0.8493 - val_loss: 0.1133
# Epoch 293/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8619 - loss: 0.1054 - val_accuracy: 0.8431 - val_loss: 0.1159
# Epoch 294/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8558 - loss: 0.1065 - val_accuracy: 0.8435 - val_loss: 0.1159
# Epoch 295/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8596 - loss: 0.1069 - val_accuracy: 0.8471 - val_loss: 0.1137
# Epoch 296/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8637 - loss: 0.1056 - val_accuracy: 0.8449 - val_loss: 0.1132
# Epoch 297/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8634 - loss: 0.1045 - val_accuracy: 0.8502 - val_loss: 0.1124
# Epoch 298/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8660 - loss: 0.1043 - val_accuracy: 0.8529 - val_loss: 0.1170
# Epoch 299/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.8653 - loss: 0.1102 - val_accuracy: 0.8511 - val_loss: 0.1119
# Epoch 300/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8647 - loss: 0.1032 - val_accuracy: 0.8466 - val_loss: 0.1146
# Epoch 301/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8608 - loss: 0.1052 - val_accuracy: 0.8457 - val_loss: 0.1138
# Epoch 302/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8629 - loss: 0.1047 - val_accuracy: 0.8435 - val_loss: 0.1144
# Epoch 303/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8598 - loss: 0.1053 - val_accuracy: 0.8475 - val_loss: 0.1145
# Epoch 304/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8599 - loss: 0.1060 - val_accuracy: 0.8489 - val_loss: 0.1135
# Epoch 305/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8627 - loss: 0.1061 - val_accuracy: 0.8466 - val_loss: 0.1130
# Epoch 306/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8610 - loss: 0.1048 - val_accuracy: 0.8547 - val_loss: 0.1122
# Epoch 307/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8665 - loss: 0.1051 - val_accuracy: 0.8578 - val_loss: 0.1128
# Epoch 308/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8686 - loss: 0.1060 - val_accuracy: 0.8520 - val_loss: 0.1118
# Epoch 309/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8641 - loss: 0.1029 - val_accuracy: 0.8444 - val_loss: 0.1139
# Epoch 310/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8612 - loss: 0.1041 - val_accuracy: 0.8449 - val_loss: 0.1131
# Epoch 311/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8637 - loss: 0.1036 - val_accuracy: 0.8453 - val_loss: 0.1133
# Epoch 312/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8641 - loss: 0.1038 - val_accuracy: 0.8480 - val_loss: 0.1120
# Epoch 313/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8644 - loss: 0.1032 - val_accuracy: 0.8551 - val_loss: 0.1103
# Epoch 314/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8678 - loss: 0.1032 - val_accuracy: 0.8542 - val_loss: 0.1137
# Epoch 315/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8650 - loss: 0.1076 - val_accuracy: 0.8484 - val_loss: 0.1121
# Epoch 316/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8618 - loss: 0.1036 - val_accuracy: 0.8471 - val_loss: 0.1132
# Epoch 317/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8606 - loss: 0.1043 - val_accuracy: 0.8511 - val_loss: 0.1136
# Epoch 318/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8648 - loss: 0.1064 - val_accuracy: 0.8520 - val_loss: 0.1113
# Epoch 319/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8661 - loss: 0.1029 - val_accuracy: 0.8395 - val_loss: 0.1159
# Epoch 320/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8568 - loss: 0.1061 - val_accuracy: 0.8440 - val_loss: 0.1159
# Epoch 321/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8600 - loss: 0.1072 - val_accuracy: 0.8480 - val_loss: 0.1147
# Epoch 322/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8616 - loss: 0.1057 - val_accuracy: 0.8440 - val_loss: 0.1150
# Epoch 323/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8594 - loss: 0.1047 - val_accuracy: 0.8435 - val_loss: 0.1197
# Epoch 324/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8617 - loss: 0.1109 - val_accuracy: 0.8342 - val_loss: 0.1192
# Epoch 325/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8531 - loss: 0.1079 - val_accuracy: 0.8440 - val_loss: 0.1161
# Epoch 326/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8597 - loss: 0.1062 - val_accuracy: 0.8524 - val_loss: 0.1137
# Epoch 327/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8670 - loss: 0.1054 - val_accuracy: 0.8480 - val_loss: 0.1145
# Epoch 328/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8625 - loss: 0.1049 - val_accuracy: 0.8506 - val_loss: 0.1158
# Epoch 329/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8650 - loss: 0.1071 - val_accuracy: 0.8506 - val_loss: 0.1123
# Epoch 330/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8627 - loss: 0.1030 - val_accuracy: 0.8506 - val_loss: 0.1104
# Epoch 331/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8656 - loss: 0.1019 - val_accuracy: 0.8547 - val_loss: 0.1117
# Epoch 332/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8669 - loss: 0.1036 - val_accuracy: 0.8449 - val_loss: 0.1156
# Epoch 333/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8577 - loss: 0.1055 - val_accuracy: 0.8440 - val_loss: 0.1166
# Epoch 334/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8569 - loss: 0.1075 - val_accuracy: 0.8515 - val_loss: 0.1122
# Epoch 335/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8626 - loss: 0.1033 - val_accuracy: 0.8556 - val_loss: 0.1103
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8660 - loss: 0.1017 - val_accuracy: 0.8480 - val_loss: 0.1138
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8613 - loss: 0.1046 - val_accuracy: 0.8524 - val_loss: 0.1143
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8600 - loss: 0.1056 - val_accuracy: 0.8538 - val_loss: 0.1114
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8653 - loss: 0.1036 - val_accuracy: 0.8431 - val_loss: 0.1127
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8607 - loss: 0.1035 - val_accuracy: 0.8489 - val_loss: 0.1111
# Epoch 341/1000
# ...
# Epoch 882/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8770 - loss: 0.0943 - val_accuracy: 0.8726 - val_loss: 0.0936
# Epoch 883/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8788 - loss: 0.0889 - val_accuracy: 0.8738 - val_loss: 0.0945
# Epoch 884/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8795 - loss: 0.0904 - val_accuracy: 0.8730 - val_loss: 0.0931
# Epoch 885/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8817 - loss: 0.0885 - val_accuracy: 0.8718 - val_loss: 0.0938
# Epoch 886/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8794 - loss: 0.0889 - val_accuracy: 0.8702 - val_loss: 0.0937
# Epoch 887/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8804 - loss: 0.0892 - val_accuracy: 0.8763 - val_loss: 0.0923
# Epoch 888/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8813 - loss: 0.0883 - val_accuracy: 0.8742 - val_loss: 0.0933
# Epoch 889/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8817 - loss: 0.0892 - val_accuracy: 0.8690 - val_loss: 0.0941
# Epoch 890/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8791 - loss: 0.0887 - val_accuracy: 0.8722 - val_loss: 0.0949
# Epoch 891/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8803 - loss: 0.0893 - val_accuracy: 0.8726 - val_loss: 0.0935
# Epoch 892/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8816 - loss: 0.0884 - val_accuracy: 0.8755 - val_loss: 0.0924
# Epoch 893/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8829 - loss: 0.0883 - val_accuracy: 0.8702 - val_loss: 0.0935
# Epoch 894/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8775 - loss: 0.0892 - val_accuracy: 0.8726 - val_loss: 0.0926
# Epoch 895/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8823 - loss: 0.0883 - val_accuracy: 0.8738 - val_loss: 0.0934
# Epoch 896/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8795 - loss: 0.0883 - val_accuracy: 0.8751 - val_loss: 0.0931
# Epoch 897/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8834 - loss: 0.0883 - val_accuracy: 0.8763 - val_loss: 0.0922
# Epoch 898/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8824 - loss: 0.0879 - val_accuracy: 0.8755 - val_loss: 0.0921
# Epoch 899/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8811 - loss: 0.0884 - val_accuracy: 0.8730 - val_loss: 0.0930
# Epoch 900/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8793 - loss: 0.0883 - val_accuracy: 0.8734 - val_loss: 0.0938
# Epoch 901/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8821 - loss: 0.0886 - val_accuracy: 0.8690 - val_loss: 0.0944
# Epoch 902/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8781 - loss: 0.0889 - val_accuracy: 0.8746 - val_loss: 0.0925
# Epoch 903/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8812 - loss: 0.0885 - val_accuracy: 0.8710 - val_loss: 0.0936
# Epoch 904/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8775 - loss: 0.0889 - val_accuracy: 0.8763 - val_loss: 0.0932
# Epoch 905/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8824 - loss: 0.0889 - val_accuracy: 0.8714 - val_loss: 0.0946
# Epoch 906/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8774 - loss: 0.0892 - val_accuracy: 0.8718 - val_loss: 0.0933
# Epoch 907/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8813 - loss: 0.0879 - val_accuracy: 0.8746 - val_loss: 0.0932
# Epoch 908/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8831 - loss: 0.0890 - val_accuracy: 0.8673 - val_loss: 0.0946
# Epoch 909/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8762 - loss: 0.0896 - val_accuracy: 0.8722 - val_loss: 0.0937
# Epoch 910/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8805 - loss: 0.0899 - val_accuracy: 0.8730 - val_loss: 0.0930
# Epoch 911/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8813 - loss: 0.0879 - val_accuracy: 0.8726 - val_loss: 0.0935
# Epoch 912/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8809 - loss: 0.0881 - val_accuracy: 0.8746 - val_loss: 0.0923
# Epoch 913/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8819 - loss: 0.0878 - val_accuracy: 0.8779 - val_loss: 0.0919
# Epoch 914/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8830 - loss: 0.0880 - val_accuracy: 0.8759 - val_loss: 0.0926
# Epoch 915/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8826 - loss: 0.0881 - val_accuracy: 0.8751 - val_loss: 0.0926
# Epoch 916/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8837 - loss: 0.0877 - val_accuracy: 0.8751 - val_loss: 0.0933
# Epoch 917/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8809 - loss: 0.0879 - val_accuracy: 0.8738 - val_loss: 0.0933
# Epoch 918/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8821 - loss: 0.0882 - val_accuracy: 0.8767 - val_loss: 0.0924
# Epoch 919/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8814 - loss: 0.0877 - val_accuracy: 0.8738 - val_loss: 0.0925
# Epoch 920/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8826 - loss: 0.0886 - val_accuracy: 0.8702 - val_loss: 0.0936
# Epoch 921/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8789 - loss: 0.0885 - val_accuracy: 0.8746 - val_loss: 0.0937
# Epoch 922/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8828 - loss: 0.0887 - val_accuracy: 0.8714 - val_loss: 0.0934
# Epoch 923/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8800 - loss: 0.0882 - val_accuracy: 0.8742 - val_loss: 0.0923
# Epoch 924/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8827 - loss: 0.0882 - val_accuracy: 0.8730 - val_loss: 0.0924
# Epoch 925/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8816 - loss: 0.0874 - val_accuracy: 0.8718 - val_loss: 0.0929
# Epoch 926/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8833 - loss: 0.0876 - val_accuracy: 0.8775 - val_loss: 0.0923
# Epoch 927/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8835 - loss: 0.0875 - val_accuracy: 0.8746 - val_loss: 0.0924
# Epoch 928/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8807 - loss: 0.0878 - val_accuracy: 0.8730 - val_loss: 0.0922
# Epoch 929/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8816 - loss: 0.0874 - val_accuracy: 0.8718 - val_loss: 0.0929
# Epoch 930/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8807 - loss: 0.0875 - val_accuracy: 0.8726 - val_loss: 0.0938
# Epoch 931/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8828 - loss: 0.0890 - val_accuracy: 0.8746 - val_loss: 0.0924
# Epoch 932/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8815 - loss: 0.0876 - val_accuracy: 0.8746 - val_loss: 0.0919
# Epoch 933/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8821 - loss: 0.0879 - val_accuracy: 0.8706 - val_loss: 0.0939
# Epoch 934/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8778 - loss: 0.0885 - val_accuracy: 0.8738 - val_loss: 0.0928
# Epoch 935/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8826 - loss: 0.0878 - val_accuracy: 0.8738 - val_loss: 0.0928
# Epoch 936/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8803 - loss: 0.0874 - val_accuracy: 0.8742 - val_loss: 0.0923
# Epoch 937/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8827 - loss: 0.0878 - val_accuracy: 0.8714 - val_loss: 0.0929
# Epoch 938/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8798 - loss: 0.0879 - val_accuracy: 0.8738 - val_loss: 0.0919
# Epoch 939/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8835 - loss: 0.0874 - val_accuracy: 0.8734 - val_loss: 0.0928
# Epoch 940/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8813 - loss: 0.0874 - val_accuracy: 0.8726 - val_loss: 0.0928
# Epoch 941/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8830 - loss: 0.0878 - val_accuracy: 0.8722 - val_loss: 0.0928
# Epoch 942/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8788 - loss: 0.0879 - val_accuracy: 0.8779 - val_loss: 0.0918
# Epoch 943/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8840 - loss: 0.0879 - val_accuracy: 0.8755 - val_loss: 0.0918
# Epoch 944/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8833 - loss: 0.0869 - val_accuracy: 0.8730 - val_loss: 0.0923
# Epoch 945/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8835 - loss: 0.0872 - val_accuracy: 0.8751 - val_loss: 0.0919
# Epoch 946/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8830 - loss: 0.0873 - val_accuracy: 0.8718 - val_loss: 0.0924
# Epoch 947/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8792 - loss: 0.0878 - val_accuracy: 0.8755 - val_loss: 0.0916
# Epoch 948/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8844 - loss: 0.0873 - val_accuracy: 0.8751 - val_loss: 0.0922
# Epoch 949/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8825 - loss: 0.0868 - val_accuracy: 0.8734 - val_loss: 0.0926
# Epoch 950/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8820 - loss: 0.0871 - val_accuracy: 0.8751 - val_loss: 0.0918
# Epoch 951/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8831 - loss: 0.0867 - val_accuracy: 0.8751 - val_loss: 0.0915
# Epoch 952/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8845 - loss: 0.0871 - val_accuracy: 0.8682 - val_loss: 0.0945
# Epoch 953/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8774 - loss: 0.0888 - val_accuracy: 0.8771 - val_loss: 0.0923
# Epoch 954/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8853 - loss: 0.0872 - val_accuracy: 0.8746 - val_loss: 0.0919
# Epoch 955/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8840 - loss: 0.0867 - val_accuracy: 0.8734 - val_loss: 0.0917
# Epoch 956/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8834 - loss: 0.0868 - val_accuracy: 0.8742 - val_loss: 0.0917
# Epoch 957/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8822 - loss: 0.0868 - val_accuracy: 0.8746 - val_loss: 0.0918
# Epoch 958/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8824 - loss: 0.0868 - val_accuracy: 0.8771 - val_loss: 0.0915
# Epoch 959/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8846 - loss: 0.0868 - val_accuracy: 0.8759 - val_loss: 0.0921
# Epoch 960/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8823 - loss: 0.0870 - val_accuracy: 0.8751 - val_loss: 0.0922
# Epoch 961/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8821 - loss: 0.0871 - val_accuracy: 0.8742 - val_loss: 0.0920
# Epoch 962/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8834 - loss: 0.0872 - val_accuracy: 0.8767 - val_loss: 0.0917
# Epoch 963/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8832 - loss: 0.0867 - val_accuracy: 0.8779 - val_loss: 0.0916
# Epoch 964/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8833 - loss: 0.0869 - val_accuracy: 0.8771 - val_loss: 0.0913
# Epoch 965/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8834 - loss: 0.0866 - val_accuracy: 0.8714 - val_loss: 0.0922
# Epoch 966/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8827 - loss: 0.0876 - val_accuracy: 0.8710 - val_loss: 0.0928
# Epoch 967/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8801 - loss: 0.0875 - val_accuracy: 0.8803 - val_loss: 0.0918
# Epoch 968/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8847 - loss: 0.0875 - val_accuracy: 0.8702 - val_loss: 0.0941
# Epoch 969/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8775 - loss: 0.0884 - val_accuracy: 0.8759 - val_loss: 0.0922
# Epoch 970/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8844 - loss: 0.0875 - val_accuracy: 0.8698 - val_loss: 0.0940
# Epoch 971/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8781 - loss: 0.0886 - val_accuracy: 0.8771 - val_loss: 0.0926
# Epoch 972/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8835 - loss: 0.0882 - val_accuracy: 0.8755 - val_loss: 0.0912
# Epoch 973/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8832 - loss: 0.0863 - val_accuracy: 0.8742 - val_loss: 0.0917
# Epoch 974/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8838 - loss: 0.0870 - val_accuracy: 0.8734 - val_loss: 0.0915
# Epoch 975/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8844 - loss: 0.0864 - val_accuracy: 0.8738 - val_loss: 0.0920
# Epoch 976/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8844 - loss: 0.0868 - val_accuracy: 0.8722 - val_loss: 0.0914
# Epoch 977/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8831 - loss: 0.0865 - val_accuracy: 0.8787 - val_loss: 0.0909
# Epoch 978/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8848 - loss: 0.0865 - val_accuracy: 0.8742 - val_loss: 0.0916
# Epoch 979/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8829 - loss: 0.0865 - val_accuracy: 0.8742 - val_loss: 0.0913
# Epoch 980/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8854 - loss: 0.0864 - val_accuracy: 0.8746 - val_loss: 0.0918
# Epoch 981/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8811 - loss: 0.0868 - val_accuracy: 0.8771 - val_loss: 0.0924
# Epoch 982/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8846 - loss: 0.0882 - val_accuracy: 0.8686 - val_loss: 0.0953
# Epoch 983/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8765 - loss: 0.0893 - val_accuracy: 0.8751 - val_loss: 0.0929
# Epoch 984/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8835 - loss: 0.0877 - val_accuracy: 0.8759 - val_loss: 0.0913
# Epoch 985/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8842 - loss: 0.0863 - val_accuracy: 0.8763 - val_loss: 0.0916
# Epoch 986/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8811 - loss: 0.0873 - val_accuracy: 0.8779 - val_loss: 0.0913
# Epoch 987/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8824 - loss: 0.0869 - val_accuracy: 0.8767 - val_loss: 0.0921
# Epoch 988/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8847 - loss: 0.0865 - val_accuracy: 0.8738 - val_loss: 0.0924
# Epoch 989/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8828 - loss: 0.0867 - val_accuracy: 0.8767 - val_loss: 0.0910
# Epoch 990/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8850 - loss: 0.0862 - val_accuracy: 0.8763 - val_loss: 0.0914
# Epoch 991/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8839 - loss: 0.0876 - val_accuracy: 0.8682 - val_loss: 0.0935
# Epoch 992/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8788 - loss: 0.0879 - val_accuracy: 0.8759 - val_loss: 0.0930
# Epoch 993/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8832 - loss: 0.0886 - val_accuracy: 0.8755 - val_loss: 0.0918
# Epoch 994/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8833 - loss: 0.0863 - val_accuracy: 0.8771 - val_loss: 0.0935
# Epoch 995/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8822 - loss: 0.0890 - val_accuracy: 0.8726 - val_loss: 0.0928
# Epoch 996/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8781 - loss: 0.0878 - val_accuracy: 0.8759 - val_loss: 0.0906
# Epoch 997/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8849 - loss: 0.0869 - val_accuracy: 0.8779 - val_loss: 0.0910
# Epoch 998/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8842 - loss: 0.0863 - val_accuracy: 0.8751 - val_loss: 0.0911
# Epoch 999/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8828 - loss: 0.0861 - val_accuracy: 0.8755 - val_loss: 0.0909
# Epoch 1000/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8829 - loss: 0.0860 - val_accuracy: 0.8734 - val_loss: 0.0914
# Best epoch: 996
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Desaturation binary model – ESADA
# {'Accuracy': np.float64(0.878), 'Precision': np.float64(0.79), 'Recall': np.float64(0.6), 'F1‑Score': np.float64(0.682), 'Dataset': 'ESADA', 'Samples': 27383}
#
# === Summary of all data‑sets (pandas DataFrame) ===
#   Dataset  Samples  Accuracy  Precision  Recall  F1‑Score
# 0  SIESTA    24918     0.879       0.78   0.571     0.659
# 1   ESADA    27383     0.878       0.79   0.600     0.682

# %%
# --------------------------------------------------------------
# Cell – Plot overall metrics (matplotlib only)
# --------------------------------------------------------------

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def plot_overall_metrics(df: pd.DataFrame, ax=None, show_samples=True):
    """
    Draw a grouped bar chart of the classification metrics for each data‑set.

    Parameters
    ----------
    df : pd.DataFrame
        Must contain the columns:
        ['Dataset', 'Accuracy', 'Precision', 'Recall', 'F1‑Score'].
        An optional column ``Samples`` can be present – it will be displayed
        as ``n=…`` above each group.
    ax : matplotlib.axes.Axes, optional
        Axis on which to draw the plot. If ``None`` a new figure/axis is created.
    show_samples : bool, optional
        If True and the column ``Samples`` exists, annotate the total number
        of samples for each data‑set.

    Returns
    -------
    matplotlib.axes.Axes
        The axis containing the plot.
    """
    # ------------------------------------------------------------------
    # 1️⃣  Prepare the axis
    # ------------------------------------------------------------------
    if ax is None:
        fig, ax = plt.subplots(figsize=(8, 5))

    # ------------------------------------------------------------------
    # 2️⃣  Normalise column names (lower‑case) for internal use
    # ------------------------------------------------------------------
    # The original helper expects lower‑case column names; we map them here.
    col_map = {
        'Dataset'   : 'dataset',
        'Accuracy'  : 'accuracy',
        'Precision' : 'precision',
        'Recall'    : 'recall',
        'F1‑Score'  : 'f1'          # note the dash in the original column name
    }
    # Create a temporary DataFrame with the expected column names
    tmp = df.rename(columns=col_map)

    # ------------------------------------------------------------------
    # 3️⃣  Plot the grouped bars
    # ------------------------------------------------------------------
    metrics   = ["accuracy", "precision", "recall", "f1"]
    n_metrics = len(metrics)

    datasets = tmp["dataset"].tolist()
    n_dsets  = len(datasets)

    ind   = np.arange(n_dsets)          # the x locations for the groups
    width = 0.18                         # the width of each bar

    # colour cycle – matplotlib default is fine, but you can customise here
    colours = plt.rcParams["axes.prop_cycle"].by_key()["color"]

    for i, metric in enumerate(metrics):
        ax.bar(
            ind + i * width,
            tmp[metric],
            width,
            label=metric.upper(),
            color=colours[i % len(colours)]
        )

    # ------------------------------------------------------------------
    # 4️⃣  Optional sample‑size annotation
    # ------------------------------------------------------------------
    if show_samples and "Samples" in df.columns:
        for i, dataset in enumerate(datasets):
            n = df.loc[df["Dataset"] == dataset, "Samples"].values[0]
            # place the text a little above the highest bar in the group
            ymax = tmp.loc[tmp["dataset"] == dataset, metrics].max().max()
            ax.text(i + width * (n_metrics - 1) / 2,
                    ymax + 0.02,
                    f"n={int(n)}",
                    ha="center", va="bottom",
                    fontsize=9, color="gray")

    # ------------------------------------------------------------------
    # 5️⃣  Cosmetics
    # ------------------------------------------------------------------
    ax.set_xticks(ind + width * (n_metrics - 1) / 2)
    ax.set_xticklabels(datasets, rotation=0)
    ax.set_ylabel("Score")
    ax.set_ylim(0, 1.05)                     # scores are in [0, 1]
    ax.set_title("Overall metrics (concatenated predictions)")
    ax.legend(loc="upper right", fontsize="small", ncol=2)

    plt.tight_layout()
    plt.show()

    return ax

# %%
plot_overall_metrics(results_df)
# Out:
# <Axes: title={'center': 'Overall metrics (concatenated predictions)'}, ylabel='Score'>
